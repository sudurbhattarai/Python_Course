# %% [markdown]
# # Setup notebook
#
# **Important: Please make sure that you can execute this notebook without errors BEFORE the first lecture and best until 10.11.2022!**
#
# This notebook is to check whether all the packages for the Excercises are installed.
#
# To install Anaconda please follow the instructions in the 'Exercise1_install_python.pdf'.
#
# To use this notebook click on a cell and press the play button above or click `shift` + `Enter`.
#
# Should something like the following message appear:
#
# ```
# ModuleNotFoundError: No module named 'xarray'
# ```
#
# You have to install the package (here xarray) in your virtual environment (terminal) using the following command line:
#
# ```
# conda install xarray
# ```

# %%
# Check if all packages are installed
# %matplotlib inline
import numpy
import pandas
import matplotlib
import xarray as xr
import scipy

# %% [markdown]
# If no import errors appears you can create your first plot running the code in the following cells. The code should compile, producing a figure below

# %%
# load some example data
airtemps = xr.tutorial.open_dataset("air_temperature")

# %%
# save the tutorial data locally on your machine. Please enter your personal and valid path to the folder location.
airtemps.to_netcdf(r'D:\MSRSGI\Winter_Semester23_24\Python\Session1\data\airtemps_loc.nc')
# Out:
# C:\Users\sudur\AppData\Local\Temp\ipykernel_9856\814405319.py:2: SerializationWarning: saving variable air with floating point data as an integer dtype without any _FillValue to use for NaNs
#   airtemps.to_netcdf(r'D:\MSRSGI\Winter_Semester23_24\Python\Session1\data\airtemps_loc.nc')

# %%
# Check if the file was properly saved at the given location (navigate to the folder) and open it from there again
airtemps_loc = xr.open_dataset(r'D:\MSRSGI\Winter_Semester23_24\Python\Session1\data\airtemps_loc.nc')

# %%
# Have a look into the data
airtemps_loc
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 75.0 72.5 70.0 67.5 65.0 ... 25.0 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 200.0 202.5 205.0 207.5 ... 322.5 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float32 ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %%
# select a the variable ''air temperature'' specific time and plot this
airtemps.air.sel(time="2014-12-31T18:00:00").plot.imshow()

# %% [markdown]
# ## The End
#
# Congrats! Now you are ready to go for the course.
